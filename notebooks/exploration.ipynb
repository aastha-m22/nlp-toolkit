# %% [markdown]
# # NLP Toolkit — Exploration Notebook
# Use this notebook to experiment with the backend modules interactively.

# %%
import sys
sys.path.insert(0, '..')

from src.tfidf     import run_tfidf
from src.word2vec  import run_word2vec
from src.ner       import run_ner
from src.sentiment import run_sentiment

# %%
# TF-IDF
result = run_tfidf(['Machine learning is great.', 'NLP is fascinating.'])
result['scratch'].head(10)

# %%
# Word2Vec
result = run_word2vec('king')
result['similar_words']

# %%
# NER
result = run_ner('Apple was founded by Steve Jobs in Cupertino, California in 1976.')
result['entities_df']

# %%
# Sentiment
result = run_sentiment('I absolutely love this product!', use_transformer=False)
result['comparison_df']
